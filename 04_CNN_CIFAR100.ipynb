# %%
import tensorflow as tf
from tensorflow.keras import models, layers
from tensorflow.keras import regularizers
import matplotlib.pyplot as plt
import numpy as np
import pickle

# %%
def load_cifar100(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f, encoding='bytes')

    images = data[b'data']
    labels = data[b'fine_labels']

    images = images.reshape(-1,3,32,32)
    images = images.transpose(0,2,3,1)

    images = images.astype("float32")/255.0
    labels = np.array(labels)

    return images,labels

# %%
# !rm -rf /content/cifar100

# %%
!7z x "/content/archive (2).zip" -o/content/cifar100
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.00GHz (50653),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 168517809 bytes (161 MiB)
#
# Extracting archive: /content/archive (2).zip
# --
# Path = /content/archive (2).zip
# Type = zip
# Physical Size = 168517809
#
# Everything is Ok
#
# Files: 4
# Size:       186301098
# Compressed: 168517809

# %%
train_images,train_labels=load_cifar100("/content/cifar100/train")
test_images,test_labels=load_cifar100("/content/cifar100/test")

# %%
model = models.Sequential([
    layers.Conv2D(32,(3,3), activation = 'relu', padding='same'),
    layers.BatchNormalization(),
    layers.Conv2D(64,(3,3), activation = 'relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),
    layers.Dropout(0.25),

    layers.Conv2D(64,(3,3), activation = 'relu', padding='same'),
    layers.BatchNormalization(),
    layers.Conv2D(128,(3,3), activation= 'relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),
    layers.Dropout(0.25),

    layers.Conv2D(128,(3,3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.Conv2D(128,(3,3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.Conv2D(128,(3,3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.Dropout(0.25),

    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.5),

    layers.Dense(100, activation = 'softmax')
])

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0005)
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(
    train_images,
    train_labels,
    epochs=30,
    batch_size=64,
    validation_data=(test_images,test_labels))
# Out:
# Epoch 1/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 26ms/step - accuracy: 0.0494 - loss: 4.3562 - val_accuracy: 0.1025 - val_loss: 3.9316
# Epoch 2/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - accuracy: 0.0863 - loss: 3.9698 - val_accuracy: 0.1292 - val_loss: 3.6733
# Epoch 3/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.1316 - loss: 3.6560 - val_accuracy: 0.2263 - val_loss: 3.1446
# Epoch 4/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.1971 - loss: 3.2928 - val_accuracy: 0.2566 - val_loss: 2.9645
# Epoch 5/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.2649 - loss: 2.9387 - val_accuracy: 0.3432 - val_loss: 2.5299
# Epoch 6/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.3253 - loss: 2.6320 - val_accuracy: 0.3673 - val_loss: 2.4812
# Epoch 7/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.3823 - loss: 2.3626 - val_accuracy: 0.4513 - val_loss: 2.0760
# Epoch 8/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.4333 - loss: 2.1293 - val_accuracy: 0.4452 - val_loss: 2.0829
# Epoch 9/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.4773 - loss: 1.9272 - val_accuracy: 0.4761 - val_loss: 1.9534
# Epoch 10/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.5144 - loss: 1.7567 - val_accuracy: 0.4861 - val_loss: 1.9543
# Epoch 11/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.5526 - loss: 1.5930 - val_accuracy: 0.4964 - val_loss: 1.9136
# Epoch 12/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.5860 - loss: 1.4521 - val_accuracy: 0.5149 - val_loss: 1.8553
# Epoch 13/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.6203 - loss: 1.3224 - val_accuracy: 0.5124 - val_loss: 1.8900
# Epoch 14/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.6497 - loss: 1.2110 - val_accuracy: 0.5395 - val_loss: 1.7738
# Epoch 15/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.6779 - loss: 1.0987 - val_accuracy: 0.5385 - val_loss: 1.8185
# Epoch 16/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.6985 - loss: 1.0102 - val_accuracy: 0.5372 - val_loss: 1.8500
# Epoch 17/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.7171 - loss: 0.9356 - val_accuracy: 0.5403 - val_loss: 1.8923
# Epoch 18/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.7364 - loss: 0.8701 - val_accuracy: 0.5468 - val_loss: 1.8892
# Epoch 19/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.7537 - loss: 0.8129 - val_accuracy: 0.5466 - val_loss: 1.8828
# Epoch 20/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.7680 - loss: 0.7566 - val_accuracy: 0.5556 - val_loss: 1.8542
# Epoch 21/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.7799 - loss: 0.7183 - val_accuracy: 0.5527 - val_loss: 1.9159
# Epoch 22/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.7899 - loss: 0.6806 - val_accuracy: 0.5558 - val_loss: 1.9375
# Epoch 23/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.8041 - loss: 0.6434 - val_accuracy: 0.5535 - val_loss: 1.8934
# Epoch 24/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.8102 - loss: 0.6134 - val_accuracy: 0.5482 - val_loss: 1.9841
# Epoch 25/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 21s 14ms/step - accuracy: 0.8178 - loss: 0.5832 - val_accuracy: 0.5486 - val_loss: 2.0079
# Epoch 26/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.8264 - loss: 0.5529 - val_accuracy: 0.5478 - val_loss: 2.0344
# Epoch 27/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.8299 - loss: 0.5436 - val_accuracy: 0.5488 - val_loss: 2.1085
# Epoch 28/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.8365 - loss: 0.5236 - val_accuracy: 0.5536 - val_loss: 1.9800
# Epoch 29/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.8428 - loss: 0.5016 - val_accuracy: 0.5454 - val_loss: 2.1608
# Epoch 30/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.8469 - loss: 0.4898 - val_accuracy: 0.5626 - val_loss: 2.1443

# %%
model.evaluate(test_images,test_labels)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5626 - loss: 2.1443
# [2.1442854404449463, 0.5626000165939331]
