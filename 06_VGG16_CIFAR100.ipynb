# %%
import tensorflow as tf
from tensorflow.keras import models,layers,datasets
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
(train_images,train_labels),(test_images,test_labels)=datasets.cifar100.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 ━━━━━━━━━━━━━━━━━━━━ 19s 0us/step

# %%
train_images=train_images/255.0
test_images=test_images/255.0

# %%
model = models.Sequential([
    layers.Conv2D(64,(3,3), activation='relu',padding='same',input_shape=(32,32,3)),
    layers.BatchNormalization(),
    layers.Conv2D(64,(3,3), activation = 'relu',padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(128,(3,3), activation = 'relu',padding='same'),
    layers.BatchNormalization(),
    layers.Conv2D(128,(3,3), activation = 'relu',padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(256,(3,3), activation='relu',padding='same'),
    layers.BatchNormalization(),
    layers.Conv2D(256,(3,3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.Conv2D(256,(3,3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(512,(3,3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.Conv2D(512,(3,3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.Conv2D(512,(3,3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.Flatten(),
    layers.Dense(1024, activation = 'relu'),
    layers.Dense(100, activation = 'softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(
    train_images,
    train_labels,
    epochs=30,
    batch_size=64,
    validation_data=(test_images,test_labels)
)
# Out:
# Epoch 1/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 63s 57ms/step - accuracy: 0.1155 - loss: 3.8371 - val_accuracy: 0.1497 - val_loss: 3.6595
# Epoch 2/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.2390 - loss: 3.0294 - val_accuracy: 0.1718 - val_loss: 3.6257
# Epoch 3/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.3373 - loss: 2.5011 - val_accuracy: 0.3055 - val_loss: 2.8867
# Epoch 4/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.4223 - loss: 2.1350 - val_accuracy: 0.3724 - val_loss: 2.3988
# Epoch 5/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.4902 - loss: 1.8448 - val_accuracy: 0.4582 - val_loss: 2.0660
# Epoch 6/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.5554 - loss: 1.5685 - val_accuracy: 0.4613 - val_loss: 2.0653
# Epoch 7/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.6169 - loss: 1.3087 - val_accuracy: 0.4778 - val_loss: 2.0825
# Epoch 8/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.6846 - loss: 1.0437 - val_accuracy: 0.5211 - val_loss: 1.9479
# Epoch 9/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.7508 - loss: 0.8001 - val_accuracy: 0.5163 - val_loss: 2.0783
# Epoch 10/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.8081 - loss: 0.6066 - val_accuracy: 0.5221 - val_loss: 2.1986
# Epoch 11/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.8602 - loss: 0.4322 - val_accuracy: 0.5196 - val_loss: 2.4376
# Epoch 12/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.8836 - loss: 0.3593 - val_accuracy: 0.5034 - val_loss: 2.7771
# Epoch 13/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.9085 - loss: 0.2840 - val_accuracy: 0.5186 - val_loss: 2.7572
# Epoch 14/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.9183 - loss: 0.2494 - val_accuracy: 0.5085 - val_loss: 2.9415
# Epoch 15/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.9194 - loss: 0.2542 - val_accuracy: 0.5198 - val_loss: 2.9789
# Epoch 16/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.9430 - loss: 0.1787 - val_accuracy: 0.5131 - val_loss: 3.1302
# Epoch 17/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.9225 - loss: 0.2552 - val_accuracy: 0.5150 - val_loss: 3.1121
# Epoch 18/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.9564 - loss: 0.1354 - val_accuracy: 0.5234 - val_loss: 3.1358
# Epoch 19/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.9413 - loss: 0.1822 - val_accuracy: 0.5274 - val_loss: 3.1400
# Epoch 20/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.9500 - loss: 0.1577 - val_accuracy: 0.5284 - val_loss: 3.2119
# Epoch 21/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.9561 - loss: 0.1360 - val_accuracy: 0.5284 - val_loss: 3.2714
# Epoch 22/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.9571 - loss: 0.1326 - val_accuracy: 0.5092 - val_loss: 3.5399
# Epoch 23/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.9569 - loss: 0.1350 - val_accuracy: 0.5373 - val_loss: 3.2282
# Epoch 24/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.9577 - loss: 0.1353 - val_accuracy: 0.5237 - val_loss: 3.3813
# Epoch 25/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.9591 - loss: 0.1306 - val_accuracy: 0.5213 - val_loss: 3.5595
# Epoch 26/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.9642 - loss: 0.1131 - val_accuracy: 0.5320 - val_loss: 3.3782
# Epoch 27/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.9703 - loss: 0.0956 - val_accuracy: 0.5300 - val_loss: 3.4764
# Epoch 28/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.9586 - loss: 0.1315 - val_accuracy: 0.5242 - val_loss: 3.4236
# Epoch 29/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.9701 - loss: 0.0946 - val_accuracy: 0.5084 - val_loss: 3.6704
# Epoch 30/30
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.9710 - loss: 0.0918 - val_accuracy: 0.5246 - val_loss: 3.4580

# %%
loss,acc = model.evaluate(test_images,test_labels)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.5246 - loss: 3.4580

# %%
print(acc*100)
# Out:
# 52.46000289916992

# %%
model.summary()

# %%
history.history.keys()

# %%
print(history.history['accuracy'])

# %%
print(model.output_shape)

# %%
model = models.Sequential([
    layers.Conv2D(32,(3,3),activation='relu',input_shape=(32,32,3)),
    layers.Flatten(),
    layers.Dense(100,activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    train_images,
    train_labels,
    epochs=1
)

# %%
print(train_labels.shape)
print(train_labels.dtype)

# %%
print(np.unique(train_labels[:100]))
